# %%
import pandas as pd

# %%
data = pd.read_csv("parkinson.csv")

# %%
data.head()
# Out:
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0     5.6431       28.199       34.398    0.00662
# 1         1   72    0    12.6660       28.447       34.894    0.00300
# 2         1   72    0    19.6810       28.695       35.389    0.00481
# 3         1   72    0    25.6470       28.905       35.810    0.00528
# 4         1   72    0    33.6420       29.187       36.375    0.00335
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.000034     0.00401      0.00317  ...        0.230       0.01438
# 1     0.000017     0.00132      0.00150  ...        0.179       0.00994
# 2     0.000025     0.00205      0.00208  ...        0.181       0.00734
# 3     0.000027     0.00191      0.00264  ...        0.327       0.01106
# 4     0.000020     0.00093      0.00130  ...        0.176       0.00679
#
#    Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# ...

# %%
data.shape
# Out:
# (5875, 22)

# %%
data.columns
# Out:
# Index(['subject#', 'age', 'sex', 'test_time', 'motor_UPDRS', 'total_UPDRS',
#        'Jitter(%)', 'Jitter(Abs)', 'Jitter:RAP', 'Jitter:PPQ5', 'Jitter:DDP',
#        'Shimmer', 'Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'Shimmer:APQ11', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'PPE'],
#       dtype='object')

# %%
data.info
# Out:
# <bound method DataFrame.info of       subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0            1   72    0     5.6431       28.199       34.398    0.00662
# 1            1   72    0    12.6660       28.447       34.894    0.00300
# 2            1   72    0    19.6810       28.695       35.389    0.00481
# 3            1   72    0    25.6470       28.905       35.810    0.00528
# 4            1   72    0    33.6420       29.187       36.375    0.00335
# ...        ...  ...  ...        ...          ...          ...        ...
# 5870        42   61    0   142.7900       22.485       33.485    0.00406
# 5871        42   61    0   149.8400       21.988       32.988    0.00297
# 5872        42   61    0   156.8200       21.495       32.495    0.00349
# 5873        42   61    0   163.7300       21.007       32.007    0.00281
# 5874        42   61    0   170.7300       20.513       31.513    0.00282
#
# ...

# %%
data.describe()
# Out:
#           subject#          age          sex    test_time  motor_UPDRS  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000
# mean     21.494128    64.804936     0.317787    92.863722    21.296229
# std      12.372279     8.821524     0.465656    53.445602     8.129282
# min       1.000000    36.000000     0.000000    -4.262500     5.037700
# 25%      10.000000    58.000000     0.000000    46.847500    15.000000
# 50%      22.000000    65.000000     0.000000    91.523000    20.871000
# 75%      33.000000    72.000000     1.000000   138.445000    27.596500
# max      42.000000    85.000000     1.000000   215.490000    39.511000
#
#        total_UPDRS    Jitter(%)  Jitter(Abs)   Jitter:RAP  Jitter:PPQ5  ...  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000  ...
# mean     29.018942     0.006154     0.000044     0.002987     0.003277  ...
# std      10.700283     0.005624     0.000036     0.003124     0.003732  ...
# ...

# %%
data.isnull().sum()
# Out:
# subject#         0
# age              0
# sex              0
# test_time        0
# motor_UPDRS      0
# total_UPDRS      0
# Jitter(%)        0
# Jitter(Abs)      0
# Jitter:RAP       0
# Jitter:PPQ5      0
# Jitter:DDP       0
# Shimmer          0
# Shimmer(dB)      0
# Shimmer:APQ3     0
# Shimmer:APQ5     0
# Shimmer:APQ11    0
# Shimmer:DDA      0
# NHR              0
# HNR              0
# RPDE             0
# DFA              0
# PPE              0
# dtype: int64

# %%
x = data.drop(['subject#', 'motor_UPDRS', 'total_UPDRS'], axis=1)

# %%
y = data[['motor_UPDRS', 'total_UPDRS']]

# %%
x.shape
# Out:
# (5875, 19)

# %%
y.shape
# Out:
# (5875, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
x_train.shape
# Out:
# (4700, 19)

# %%
x_test.shape
# Out:
# (1175, 19)

# %%
y_train.shape
# Out:
# (4700, 2)

# %%
y_test.shape
# Out:
# (1175, 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred[:10]
# Out:
# array([[19.856561  , 28.24114869],
#        [16.38439741, 20.06407714],
#        [16.25567865, 22.4041273 ],
#        [18.53077086, 25.97878127],
#        [21.80387186, 28.88044124],
#        [20.16761234, 27.64378999],
#        [19.09104   , 26.88694587],
#        [23.85914981, 33.91356637],
#        [21.66746921, 29.89299173],
#        [17.97395447, 23.14563521]])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)
import numpy as np
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
mae,rmse,r2
# Out:
# (7.203593321090503, np.float64(8.640628389310352), 0.14020861495632037)

# %%
import numpy as np
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# np.float64(8.640628389310352)

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.14020861495632037

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(random_state=42)

# %%
rf_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred_rf = rf_model.predict(x_test)

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2_rf = r2_score(y_test, y_pred_rf)

mae_rf, rmse_rf, r2_rf
# Out:
# (0.6033893557446803, np.float64(1.3670392378859868), 0.9785694054859579)

# %%
import pandas as pd

importance = rf_model.feature_importances_

feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importance
})

feature_importance.sort_values(by='Importance', ascending=False)
# Out:
#           Feature  Importance
# 0             age    0.662430
# 17            DFA    0.091677
# 1             sex    0.080884
# 2       test_time    0.073132
# 4     Jitter(Abs)    0.017090
# 15            HNR    0.014014
# 16           RPDE    0.013113
# 18            PPE    0.008161
# 14            NHR    0.004954
# 9     Shimmer(dB)    0.004537
# 12  Shimmer:APQ11    0.004474
# 11   Shimmer:APQ5    0.004319
# 10   Shimmer:APQ3    0.004033
# 13    Shimmer:DDA    0.003880
# 8         Shimmer    0.003419
# 3       Jitter(%)    0.002536
# 6     Jitter:PPQ5    0.002505
# 7      Jitter:DDP    0.002427
# 5      Jitter:RAP    0.002414

# %%
import matplotlib.pyplot as plt

feature_importance.sort_values(by='Importance').plot(
    x='Feature', y='Importance', kind='barh'
)

plt.title("Feature Importance for Parkinson Severity Prediction")
plt.show()

# %%
sample_patient = [[
72, 0, 5.6431,
0.00662, 0.000034, 0.00401, 0.00317, 0.01203,
0.230, 0.01438, 0.01309, 0.01700, 0.02100,
0.365, 0.02100, 21.640,
0.418, 0.548, 0.223
]]

# %%
import pandas as pd

sample_df = pd.DataFrame(sample_patient, columns=X.columns)

prediction = rf_model.predict(sample_df)

print("Predicted Parkinson Severity:", prediction[0])
# Out:
# Predicted Parkinson Severity: [26.92002 33.85964]

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# Load dataset
data = pd.read_csv("parkinson.csv")

# Prepare features
X = data.drop(['subject#','motor_UPDRS','total_UPDRS'], axis=1)
y = data[['motor_UPDRS','total_UPDRS']]

# Train model
model = RandomForestRegressor()
model.fit(X, y)
# Out:
# RandomForestRegressor()
